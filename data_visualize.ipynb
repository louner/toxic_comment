# %%
import pandas as pd
from ggplot import *

# %%
df = pd.read_csv('log/metrics.csv')
#ggplot(df, aes(x='x')) + geom_point(aes(y='train_err', color='train_err'))
ggplot(df, aes(x='x')) + geom_point(aes(y='train_err', color='train_err')) + geom_point(aes(y='val_err', color='val_err'))
# Out:
# <ggplot: (-9223363242952056944)>

# %%
df = pd.DataFrame([(x, x*x, 1/x) for x in range(1,10)], columns=['x', 'y1', 'y2'])
df.head()
# Out:
#    x  y1        y2
# 0  1   1  1.000000
# 1  2   4  0.500000
# 2  3   9  0.333333
# 3  4  16  0.250000
# 4  5  25  0.200000

# %%
ggplot(df, aes(x='x')) + geom_point(aes(y='y1', color='y1')) + geom_point(aes(y='y2', color='y2'))
# Out:
# <ggplot: (8731866229694)>
